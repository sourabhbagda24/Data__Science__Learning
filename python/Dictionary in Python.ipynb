# %% [markdown]
# # Python Dictionaries\
# - Dictionary are used to store the data in the value of Key: value format
# - The Dictionary are in orderd form, due to which we can access it throght the indexes
# - the key:value pair are changable ,and do not allow duplicates
# - Dictionary are written with curly braces
# #time complexity
# - O(1) insert,delete

# %%
first_dict = {
  'name':'piyush',
  'gender':'male',
  'age':22,
  'age':24

}
print(first_dict["name"])

# %%
print(first_dict["age"])

# %% [markdown]
# # Duplicates Not Allowed
# -  Dictionaries cannot have two items with the same key:

# %%
print(first_dict)

# %%
print(len(first_dict))

# %% [markdown]
# #dictionary item data type
# - it can be int,float,char,strings,boolean etc

# %%
firt_dict = {
  'name':'piyush',
  'class':'data-sceoce',
  'age':22,
  'smoker':False
}
print(first_dict)

# %%
print(type(firt_dict))

# %% [markdown]
# #constructor in dict

# %%
first = dict(name='piyus',age=22,smkoer=False,Drinker=True)
print(first)

# %% [markdown]
# #Accessing Items
# - You can access the items of a dictionary by referring to its key name, inside square brackets:

# %%
thisFact = {
  'name':'piyush',
  'age':22,
  'class':'AI/ML',
  'smoker': False,
  'Drinker':False

}
x = thisFact["name"]

# %%
print(x)

# %% [markdown]
# # There is also a method called get() that will give you the same result:

# %%
y = thisFact.get("name")
print(y)

# %%
x = thisFact.keys()
print(x)

# %%
car = {
    'name':'Audi',
    'Model':'A6',
    'year':2025,
    'colour':'Black'
}
print(car['year'])
car['year'] = '2026'
print(car['year'])

# %% [markdown]
# # The keys() method will return a list of all the keys in the dictionary.

# %% [markdown]
# the valus() return the values of the dictionary

# %%
x = car.values()
print(x)

# %% [markdown]
# # items() method will return each item in a dictionary, as tuples in a list.l

# %%
x = car.items()
print(x)

# %%
if 'model' in car:
    print("yes")

# %% [markdown]
# - The update() method will update the dictionary with the items from the given argument.

# %%
car.update({'year':2025})
print(car)

# %%
# to add an item in the dictionary
one = {
    'name':'piyush',
    'age':22
}
print(one)
one['student'] = True
print(one)

# %% [markdown]
# Remove dictionary itmens we use pop()

# %%
one.pop('age')
print(one)

# %% [markdown]
# - The popitem() method removes the last inserted item

# %%
one.popitem()
print(one)

# %% [markdown]
# - The del keyword can also delete the dictionary completely:

# %%
del one
print(one)
# #this will cause an error because "thisdict" no longer exists.

# %%
one = {
    'name':'piyush',
    'age':22,
    'student':True,
    'address':{
        'street':'123 Main St',
        'city':'New York'
    }
}
for x,y in one.items():
    print(x,y)

for x in one:
    print(one[x])
for x in one.items():
    print(x)
for x in one:
    print(x)        

for x in one.values():
    print(x)
for x in one.keys():
    print(x)

# %% [markdown]
# #copy a dictionary there are two method
# first is use copy()
# dist()

# %%
one = {
    'name':'piyush',
    'age':22,
    'student':True,
    'address':{
        'street':'123 Main St'
    }
}
two = one.copy()
print(two.items())
three = dict(one)
print(three.items())

# %%
family = {
    'child1':{
        'name':'anna',
        'age':22
    },
    'child2':{
        'name':'bann',
        'age':45
    }
}
print(family['child1']['name'])

# %%
child1 = {
    'name':'anna',
    'year' :22
}
child2 = {
    'name':'danna',
    'year' :211
}
child3 = {
    'name':'banna',
    'year' :2452
}

myfamily = {
    'child1':child1,
    'child2':child2,
    'child3':child3
}
print(myfamily['child1']['name'])

# %%
for x,obj in myfamily.items():
    print(x)
    for y in obj:
        print(y + ": "+obj[y])

# %%
for x, obj in myfamily.items():
    print(x)
    for y in obj:
        print(f'{y} :  {obj[y]}')

# %% [markdown]
# # Dictionary Methods
# - Python has a set of built-in methods that you can use on dictionaries.
#
# Method	Description
# - clear()	Removes all the elements from the dictionary
# - copy()	Returns a copy of the dictionary
# - fromkeys()	Returns a dictionary with the specified keys and value
# - get()	Returns the value of the specified key
# - items()	Returns a list containing a tuple for each key value pair
# - keys()	Returns a list containing the dictionary's keys
# - pop()	Removes the element with the specified key
# - popitem()	Removes the last inserted key-value pair
# - setdefault()	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
# - update()	Updates the dictionary with the specified key-value pairs
# - values()	Returns a list of all the values in the dictionary
