# %% [markdown]
# # Tuple
# - Tuples are used to store multiple items in a single variable.
#
# - Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# - A tuple is a collection which is ordered and unchangeable.
#
# - Tuples are written with round brackets ->  ( )

# %%
thistuple = ('apple',1,3,'banana')
print(thistuple)

# %% [markdown]
# #Tuple Items
# - Tuple items are ordered, unchangeable, and allow duplicate values.
#
# - Tuple items are indexed, the first item has index [0], the second item has index [1] etc.
#
# # Ordered
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
#
# # Unchangeable
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.
#
# # Allow Duplicates
# Since tuples are indexed, they can have items with the same value:

# %%
fruits = ('apple','apple',1,1,'banana')
print(fruits)

# %%
print(len(fruits))

# %% [markdown]
# #To create a tuple with only one item, you have to add
# #a comma after the item, otherwise Python will not recognize it as a tuple

# %%
one = ('apple')
print(one)
print(type(one))

# %%
two = ('apple',)
print(two,type(two))

# %% [markdown]
# #the tuple constructor is defined with double (())

# %%
one = tuple(('apple','banan','eatermelon'))
print(one,type(one))
print(one)

# %% [markdown]
# #now we will learn how to access the tuple

# %%
print(one[1])
print(one[:])
print(one[-2:-1]) #means pichese index move hogi right to left    -4 -3  -2 -1
print(one[:-1])
print(one[-1])

# %% [markdown]
# #chekc if the item exost using if in

# %%
if 'apple' in one:
  print('yes')
else:
  print(one)

# %% [markdown]
# # we can not change the value of tuple once
# #created but we can change it how:
# # first  the tuple is created x = ('app','bat','cat','dog')
# # now we will convert the tuple into list
# # y = list(x)
# # y[1] = "banan"
# # x = tuple(y)
# #print(x)

# %%
x= ('apple','bat','cat','dog')
print(x)
y = list(x)
y[1] = "banan"
x = tuple(y)
print(x)

# %% [markdown]
# #similary we can do append,remove, pop,push ,add and
# #del the item in the tuple

# %%
x = (1,2,3,4)
print(x)
y = list(x)
y.append(5)
x = tuple(y)
print(x)

# %% [markdown]
# #Unpacking a Tuple
# #When we create a tuple, we normally assign values to it. This is called "packing" a tuple:

# %%
fruits = ('appale','banan','cherry','dragonfruit','eggplant')
(green,yellow,*red) = fruits
print(green)
print(yellow)
print(red)

# %%
fruits = ('appale','banan','cherry','dragonfruit','eggplant')
(green,*yellow,red) = fruits
print(green)
print(yellow)
print(red)

# %% [markdown]
# # loop through the tuple

# %%
this = ('apple','banana','cherry')
for i in this:
  print(i)

# %% [markdown]
# #join the tuple and multiply the tulpe

# %%
tu = (1,2,3,4)
tu2 = (5,6,7,8)
tu3= tu + tu2
print(tu3)
print(tu3*2)

# %% [markdown]
# # Tuple Methods
# # Python has two built-in methods that you can use on tuples.
#
# # Method	Description
# #count()	Returns the number of times a specified value occurs in a tuple
# #index()	Searches the tuple for a specified value and returns the position of where it was found

# %%
x = tu3*2
cnt = x.count(5)
print(cnt)

# %%
idx = x.index(4)
print("this is the tuple",x)
print("the 4 is at the index of",idx)
