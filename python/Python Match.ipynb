# %% [markdown]
# - The match statement is used to
# perform different actions
# based on different
#
# conditions.
# it is like cases in c and c++

# %% [markdown]
# - match expression:
# -   case x:
# -     code block
# -   case y:
# -     code block
# -   case z:
# -     code block

# %% [markdown]
# - The match expression is evaluated once.
# - The value of the expression is compared with the values of each case.
# - If there is a match, the associated block of code is executed.
# - The example below uses the weekday number to print the weekday name:

# %%
day = 2
match day:
  case 1:
    print("mond")
  case 2:
      print("tue")
  case 3:
    print("wed")
  case _:
    print("this is default")

# %%
day =4
match day:
    case 1 |2|3|4:
        print("under 4")
    case 5|6|7:
        print("under 7")
    case _:
        print("this is default")

# %%
month = 3
case: 1|2|3|4 if month ==3:
    print("march")
case: 5|6|7 if month == 5:
    print("may")
case: _
    print("default")
