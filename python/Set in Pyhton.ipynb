# %% [markdown]
# # Set
# #Sets are used to store multiple items in a single variable.
#
# #Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# #A set is a collection which is unordered, unchangeable*, and unindexed.
#
# # Set items are unchangeable, but you can remove items and add new items.
#
# # sets are written with the {} braces

# %%
set1 = {'apple','banan','cheery'}
print(set1)

# %% [markdown]
# # Set Items
# Set items are unordered, unchangeable, and do not allow duplicate values.

# %%
set1 = {1,2,1,1,1,1,1}
print(set1)

# %% [markdown]
# # Unordered
# Unordered means that the items in a set do not have a defined order.
#
# Set items can appear in a different order every time you use them, and cannot be referred to by index or key.

# %%
one = {2,1,3,41,1,2,4}
print(one)
print(one)

# %% [markdown]
# if we access through index it will give error

# %%
print(one[2])
print(one[0])

# %% [markdown]
# How to find the length of the set

# %%
print(len(one))

# %%
print(type(one))

# %% [markdown]
# The set() Constructor
# It is also possible to use the set() constructor to make a set.

# %%
one = set((1,2,3,4,2,43,2,2,342))
print(one)

# %% [markdown]
# Access Items:
# You cannot access items in a set by referring to an index or a key.
#
# But you can loop through the set items using a for loop, or ask if a specified value is present in a set, by using the in keyword.

# %%
for i in one:
  print(i)

# %%
if 2 in one:
  print("yes")

# %% [markdown]
# Add Items
# Once a set is created, you cannot change its items, but you can add new items.
#
# To add one item to a set use the add() method.

# %%
one.add(10)
print(one)

# %% [markdown]
# #Add Sets
# #To add items from another set into the current set, use the update() method.

# %%
one = {1,2,3,4,5}
two = {4,2,35,6,55,44,22}
one.update(two)
print(one)

# %% [markdown]
# #Remove Item
# #To remove an item in a set, use the remove(), or the discard() method.

# %%
one.remove(10,5,6)
print(one)

# %%
one.remove(10)  # here the errors is because the 10 is not there in one instad here we will write discard instead of remove
# means if the value is not there it will not give the erro
one.remove(5)
print(one)

# %%
one.discard(10)
one.remove(2)
one.remove(1)
print(one)

# %% [markdown]
# #pop
# # it remove a random element throught the set

# %%
one.pop()
print(one)

# %% [markdown]
# clear  makes the set emoyth and del is make the set delete

# %%
one.clear()
print(one)

# %%
one = {1,344,5,5,5}
del one

# %%
print(one)

# %% [markdown]
# #Join Sets
# #There are several ways to join two or more sets in Python.
#
# #The union() and update() methods joins all items from both sets.
#
#
#
# #The intersection() method keeps ONLY the duplicates.
#
#
#
# #The difference() method keeps the items from the first set that are not in the other set(s).
#
#
#
# #The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %%
one = {1,2,3,4,45}
two = {245,4,548,84,84,84,84,7851,618,4154}
one.union(two)
print(one)
one.intersection(two)
print(one)
one.difference(two)
print(one)
one.symmetric_difference(two)
print(one)

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)

# %%
myset = set1 | set2 | set3 |set4
print(myset)

# %%
set6 = set1 & set2
print(set6)

# %% [markdown]
# #Symmetric Differences
# #The symmetric_difference() method will keep only the elements that are NOT present in both sets.

# %%
set1 = {1,2,3,4}
set2 = {1,2,3,4,5}
set3 = set1.symmetric_difference(set2)
print(set3)

# %%
#we can also use( ^ )this operator aslo
set3 = set1 ^ set2
print(set3)

# %% [markdown]
# #The symmetric_difference_update() method will also
# # keep all but the duplicates, but it will change the original set instead of returning a new set.

# %%
set1 = {1,2,3,4}
set2 = {1,2,3,4,2,5,6,9}
set1.symmetric_difference_update(set2)
print(set1)

# %% [markdown]
# # Python frozenset
# - frozenset is an immutable version of a set.
# -  Like sets, it contains unique, unordered, unchangeable elements.
#
# -  Unlike sets, elements cannot be added or removed from a frozenset.

# %%
set1  = frozenset({'apple','babnan','cat'})
print(set1)
print(type(set1))

# %% [markdown]
# #Frozenset Methods
# - Being immutable means you cannot add or remove elements. However, frozensets support all non-mutating operations of sets.
#
# - Method	Shortcut	Description	Try it
# - copy()	 	Returns a shallow copy
# - difference()	-	Returns a new frozenset with the difference
# - intersection()	&	Returns a new frozenset with the intersection
# - isdisjoint()	 	Returns whether two frozensets have an intersection
# - issubset()	<= / <	Returns True if this frozenset is a (proper) subset of another
# - issuperset()	>= / >	Returns True if this frozenset is a (proper) superset of another
# - symmetric_difference()	^	Returns a new frozenset with the symmetric differences
# - union()	|	Returns a new frozenset containing the union

# %% [markdown]
# # Set Methods
# -  Python has a set of built-in methods that you can use on sets.
#
# Method	Shortcut	Description
# - add()	 	Adds an element to the set
# - clear()	 	Removes all the elements from the set
# - copy()	 	Returns a copy of the set
# - difference()	-	Returns a set containing the difference between two or more sets
# - difference_update()	-=	Removes the items in this set that are also included in another, specified set
# - discard()	 	Remove the specified item
# - intersection()	&	Returns a set, that is the intersection of two other sets
# - intersection_update()	&=	Removes the items in this set that are not present in other, specified set(s)
# - isdisjoint()	 	Returns whether two sets have a intersection or not
# - issubset()	<=	Returns True if all items of this set is present in another set
# -  	<	Returns True if all items of this set is present in another, larger set
# - issuperset()	>=	Returns True if all items of another set is present in this set
# -  	>	Returns True if all items of another, smaller set is present in this set
# - pop()	 	Removes an element from the set
# - remove()	 	Removes the specified element
# - symmetric_difference()	^	Returns a set with the symmetric differences of two sets
# - symmetric_difference_update()	^=	Inserts the symmetric differences from this set and another
# - union()	|	Return a set containing the union of sets
# - update()	|=	Update the set with the union of this set and others
