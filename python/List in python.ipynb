# %% [markdown]
# #List
# -  a list is a fundamental data structure in Python.
# -  It is used to store an ordered collection of items, which can be of different data types, including integers, strings, or even other lists.
# -  Lists are created by enclosing elements within square brackets and separating them with commas.
# -  They are mutable, meaning their elements can be changed after the list is created.
# -  This mutability allows for adding, removing, or modifying items within the list.
# -  Lists are also indexed, with the first item having an index of 0, and they allow duplicate values.
# -  The underlying implementation of Python lists is based on dynamic arrays, which are optimized for fast fixed-length operations.
# -  it allows duplicates
# -  When we say that lists are ordered, it means that the items have a defined order, and that order will not change
# -  If you add new items to a list, the new items will be placed at the end of the list.
# - The list is changeable, meaning that we can change, add, and remove items in a list after it has been created.

# %%
myfruits = ['apple','banan','cherry','dragonfruit']
print(myfruits)

# %%
print(myfruits[0])
print(myfruits[-1])
print(myfruits[1:3])
myfruits = ['mango','orange']
print(myfruits)

# %%
print(len(myfruits))
print(type(myfruits))

# %%
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)

# %%
if "mango" in myfruits:
    print("apple is there in the list")
else:
    print("apple not there in the list")

# %%
myfruits[1] = "gavava"
print(myfruits)

# %% [markdown]
# replicing item in the list

# %%
myfruits = ['apple','banana','mango','gavava']
myfruits[1:3] = ['dragonfruit','orange']
print(myfruits)

# %% [markdown]
# inserting elements in the list

# %%
myfruits.insert(2,"watermelon")
print(myfruits)

# %% [markdown]
# append: it add the elemnt at the last of the list
# similary there are many in build function

# %%
myfruits.append("strawberry")
print(myfruits)
j = myfruits.count("apple")

print(j)
print(myfruits.reverse())

# %% [markdown]
# to append elements from another list to the current list, use the extend() method.

# %%
mylist1 = [1,2,3,4]
mylist2 = [5,2,6,8]
mylist1.extend(mylist2)
mylist1.reverse()
print(mylist1)

mylist1.sort()
print(mylist1)
print(mylist1.index(5))
mylist1.remove(2)
mylist1.reverse()
print(mylist1)

# %% [markdown]
# we can use del keyword to remove the element also, pop,remove

# %%
mylist1.pop(1)
print(mylist1)

# %%
mylist1.pop()
print(mylist1)

# %%
mylist1.remove(2)
print(mylist1)

# %%
mylist1 = [1,2,3,5,6,31]
print(mylist1)
del mylist1

# %%
mylist1 = [1,2,3,5,6,31]
mylist1.clear()
print(mylist1)

# %%
mylist1 = [1,2,3,5,6,31]
for  x in mylist1:
    print(x)

# %%
for i in range(len(mylist1)):
    print(mylist1[i])

# %%
i = 0
while(i<len(mylist1)):
    print(mylist1[i])
    i+=1

# %%
[print(x) for x in mylist1]

# %% [markdown]
# #List Comprehension
# - List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.

# %%
fruits = ['apple','banana','cherry',]
newlist = []
for x in fruits:
  if 'a' in x:
    newlist.append(x)
print(newlist)

# %%
fruits = ['apple','banana','cherry']
newlist = [x for x in fruits if 'b' in x]
print(newlist)

# %% [markdown]
# #Iterable
# - The iterable can be any iterable object, like a list, tuple, set etc.

# %%
new = [ x for x in range(10)]
print(new)

# %%
new = [ x for x in range(10) if x%2 == 0]
print(new)

# %%
new = [x for x in range(20) if x%2 != 0 and x%3 != 0]
print(new)

# %% [markdown]
# #Expression
# -The expression is the current item in the iteration, but it is also the outcome, which you can manipulate before it ends up like a list item in the new list:

# %%
fruits = ['apple','banana','cherry','watermelon']
new = [x for x in fruits if 'a' in x]
print(new)

# %%
new = ['hello' for x in fruits if 'c' in x]
print(new)

# %%
new = [ 'hello' for x in fruits]
print(new)

# %%
new = [x if x!='banana' else 'orange' for x in fruits]
print(new)

# %% [markdown]
# - sort list:
# - sort the list in ascending or descending order
# - for ascending we used list_name.sort()
# - but for descending we use list_name.sort(reverse = True)
# - By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters:

# %% [markdown]
# - we can use built-in functions as key functions when sorting a list.
#
# - So if you want a case-insensitive `sort` function, use str.lower as a key function:

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)

# %% [markdown]
# Python - Copy Lists
# # Copy a List
# - You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.
# `mylist = thislist.copy()`
#
# # Use the list() method
# - Another way to make a copy is to use the built-in method list().
# `mylist = list(thislist)`
#
# # Use the slice Operator
# - You can also make a copy of a list by using the : (slice) operator.
# `mylist = thislist[:]`

# %%
mylist = [1,2,3,4,5]
newlist = mylist.copy()
print("this is using copy a list",newlist)
newlist2 = list(mylist)
print("this is used mehtod list",newlist2)
newlist3 = mylist[:]
print("this is done by slcice operator",newlist3)

# %% [markdown]
# # Join Two Lists
# - There are several ways to join, or concatenate, two or more lists in Python.
# - One of the easiest ways are by using the + operator.

# %%
list1  = [1,2,3,4]
list2 = ['a','v','d',1,2,4,22]
list3 = list1+list2
print(list3)

# %%
for x in list2:
    list1.append(x)
print(list1)

# %% [markdown]
# -  use the extend() method, where the purpose is to add elements from one list to another list:

# %%
list1.extend(list2)
print(list1)

# %% [markdown]
# - clear()	Removes all the elements from the list
# - copy()	Returns a copy of the list
# - count()	Returns the number of elements with the specified value
# - extend()	Add the elements of a list (or any iterable), to the end of the current list
# - index()	Returns the index of the first element with the specified value
# - insert()	Adds an element at the specified position
# - pop()	Removes the element at the specified position
# - remove()	Removes the item with the specified value
# - reverse()	Reverses the order of the list
# - sort()	Sorts the list
