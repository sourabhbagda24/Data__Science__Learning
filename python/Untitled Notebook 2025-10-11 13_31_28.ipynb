# %%
x = lambda a,b:a+b
print(x(5,3))

# %%
sa = [x for x in range(1,10) if x%2 == 0]
print(sa)

# %%
marks = [99,90,80,85]
def grade(marks):
    if marks >= 90:
        return 'A'
    elif marks >= 90 and marks<=90:
        return 'B'
score = map(grade,marks)
print(next(score))
print(next(score))   
print(next(score)) 
print(list(score))

# %%
marks = [99,90,80,85]
def grade(marks):
    if marks >= 90:
        return 'A'
    elif marks <= 90 and marks>=80:
        return 'B'
score = map(grade,marks)
# print(next(score))
# print(next(score))
# print(next(score))
print(list(score))

# %%
s = "2025 is a current year"
x = list(s.split(" "))
x[0], x[-1] = x[-1], x[0]
print(x)
s_new = " ".join(x)
print(s_new)
